# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# %%
# Configurations
input_directory = r"C:\Users\33658\Documents\Celebrity Faces Cropped"  # Dataset cropped
image_size = (224, 224)  # Taille des images pour MobileNetV2
learning_rate = 0.0008
batch_size = 32

# %%
# Étape 1 : Préparer les données
datagen = ImageDataGenerator(
    rescale=1.0 / 255,  # Normaliser les pixels
    validation_split=0.2,  # 20% pour la validation
    horizontal_flip=True,  # Augmenter les données
    zoom_range=0.2
)

train_generator = datagen.flow_from_directory(
    input_directory,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    subset="training"
)

validation_generator = datagen.flow_from_directory(
    input_directory,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 601 images belonging to 9 classes.
# Found 146 images belonging to 9 classes.

# %%
# Étape 2 : Construire le modèle
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)
predictions = Dense(train_generator.num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Geler les couches du modèle de base
for layer in base_model.layers:
    layer.trainable = False

# %%
# Étape 3 : Compiler le modèle
model.compile(optimizer=Adam(learning_rate=learning_rate),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Configurer Early Stopping
early_stopping = EarlyStopping(
    monitor="val_loss",  # Surveiller la perte sur l'ensemble de validation
    patience=25,          # Nombre d'époques sans amélioration avant d'arrêter
    restore_best_weights=True,  # Restaurer les poids correspondant à la meilleure époque
    verbose=1            # Afficher un message lorsque l'entraînement s'arrête
)

# %%
# Étape 4 : Entraîner le modèle
num_epochs = 125

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=num_epochs,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[early_stopping]  # Ajouter le callback Early Stopping
)

import matplotlib.pyplot as plt

# Courbe de perte
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# Courbe de précision (si surveillée)
if 'accuracy' in history.history:
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.show()
# Out:
# Epoch 1/125
# C:\Users\33658\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.2077 - loss: 2.2648 - val_accuracy: 0.5000 - val_loss: 1.5835
# Epoch 2/125
#  1/18 ━━━━━━━━━━━━━━━━━━━━ 7s 457ms/step - accuracy: 0.4375 - loss: 1.6818
# C:\Users\33658\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4375 - loss: 1.6818 - val_accuracy: 0.4444 - val_loss: 1.4326
# Epoch 3/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 650ms/step - accuracy: 0.5201 - loss: 1.4520 - val_accuracy: 0.6484 - val_loss: 1.1665
# Epoch 4/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6250 - loss: 1.3977 - val_accuracy: 0.7222 - val_loss: 1.1949
# Epoch 5/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5948 - loss: 1.1833 - val_accuracy: 0.6797 - val_loss: 0.9795
# Epoch 6/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8438 - loss: 0.8474 - val_accuracy: 0.8889 - val_loss: 0.6680
# Epoch 7/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 680ms/step - accuracy: 0.7453 - loss: 0.8978 - val_accuracy: 0.7969 - val_loss: 0.8407
# Epoch 8/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7188 - loss: 0.8951 - val_accuracy: 0.8889 - val_loss: 0.6337
# Epoch 9/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 712ms/step - accuracy: 0.7820 - loss: 0.7579 - val_accuracy: 0.8438 - val_loss: 0.6933
# Epoch 10/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6562 - loss: 0.7741 - val_accuracy: 0.6111 - val_loss: 1.0717
# Epoch 11/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 813ms/step - accuracy: 0.8148 - loss: 0.6364 - val_accuracy: 0.7656 - val_loss: 0.6883
# Epoch 12/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6562 - loss: 0.9556 - val_accuracy: 0.9444 - val_loss: 0.3575
# Epoch 13/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 750ms/step - accuracy: 0.8012 - loss: 0.6634 - val_accuracy: 0.8047 - val_loss: 0.6666
# Epoch 14/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9375 - loss: 0.4263 - val_accuracy: 0.9444 - val_loss: 0.3609
# Epoch 15/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 647ms/step - accuracy: 0.8663 - loss: 0.5187 - val_accuracy: 0.8125 - val_loss: 0.5569
# Epoch 16/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9062 - loss: 0.4692 - val_accuracy: 0.7778 - val_loss: 0.8185
# Epoch 17/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 654ms/step - accuracy: 0.8517 - loss: 0.5253 - val_accuracy: 0.8125 - val_loss: 0.5485
# Epoch 18/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8750 - loss: 0.3896 - val_accuracy: 0.8889 - val_loss: 0.4456
# Epoch 19/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 701ms/step - accuracy: 0.8882 - loss: 0.4407 - val_accuracy: 0.8047 - val_loss: 0.5987
# Epoch 20/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9062 - loss: 0.4316 - val_accuracy: 0.7222 - val_loss: 0.5833
# Epoch 21/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 642ms/step - accuracy: 0.9034 - loss: 0.4183 - val_accuracy: 0.8203 - val_loss: 0.5999
# Epoch 22/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7812 - loss: 0.5394 - val_accuracy: 0.8889 - val_loss: 0.2897
# Epoch 23/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 651ms/step - accuracy: 0.8992 - loss: 0.3919 - val_accuracy: 0.8750 - val_loss: 0.4162
# Epoch 24/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7812 - loss: 0.4833 - val_accuracy: 0.7778 - val_loss: 0.8316
# Epoch 25/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 663ms/step - accuracy: 0.9097 - loss: 0.3381 - val_accuracy: 0.8594 - val_loss: 0.4465
# Epoch 26/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9375 - loss: 0.2731 - val_accuracy: 0.7222 - val_loss: 0.6588
# Epoch 27/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 698ms/step - accuracy: 0.9222 - loss: 0.3176 - val_accuracy: 0.8359 - val_loss: 0.4623
# Epoch 28/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9200 - loss: 0.2417 - val_accuracy: 0.8889 - val_loss: 0.5647
# Epoch 29/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - accuracy: 0.9020 - loss: 0.3275 - val_accuracy: 0.8984 - val_loss: 0.3820
# Epoch 30/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7812 - loss: 0.4330 - val_accuracy: 0.9444 - val_loss: 0.2307
# Epoch 31/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 860ms/step - accuracy: 0.9475 - loss: 0.2180 - val_accuracy: 0.8672 - val_loss: 0.4104
# Epoch 32/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9375 - loss: 0.2522 - val_accuracy: 0.8889 - val_loss: 0.3421
# Epoch 33/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 697ms/step - accuracy: 0.9315 - loss: 0.2594 - val_accuracy: 0.8359 - val_loss: 0.4331
# Epoch 34/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9688 - loss: 0.2244 - val_accuracy: 0.8889 - val_loss: 0.4193
# Epoch 35/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 698ms/step - accuracy: 0.9493 - loss: 0.2177 - val_accuracy: 0.8594 - val_loss: 0.4215
# Epoch 36/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9375 - loss: 0.2229 - val_accuracy: 1.0000 - val_loss: 0.1654
# Epoch 37/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 775ms/step - accuracy: 0.9244 - loss: 0.2837 - val_accuracy: 0.9141 - val_loss: 0.3202
# Epoch 38/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9688 - loss: 0.2199 - val_accuracy: 0.8333 - val_loss: 0.4437
# Epoch 39/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 18s 887ms/step - accuracy: 0.9608 - loss: 0.1926 - val_accuracy: 0.8828 - val_loss: 0.3945
# Epoch 40/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8750 - loss: 0.2541 - val_accuracy: 1.0000 - val_loss: 0.1122
# Epoch 41/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 849ms/step - accuracy: 0.9718 - loss: 0.1743 - val_accuracy: 0.8750 - val_loss: 0.3899
# Epoch 42/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9688 - loss: 0.2268 - val_accuracy: 0.8889 - val_loss: 0.3613
# Epoch 43/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 785ms/step - accuracy: 0.9770 - loss: 0.1654 - val_accuracy: 0.8516 - val_loss: 0.3972
# Epoch 44/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 0.1244 - val_accuracy: 0.9444 - val_loss: 0.2491
# Epoch 45/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 650ms/step - accuracy: 0.9721 - loss: 0.1695 - val_accuracy: 0.9219 - val_loss: 0.3340
# Epoch 46/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.1975 - val_accuracy: 0.8333 - val_loss: 0.3420
# Epoch 47/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 720ms/step - accuracy: 0.9521 - loss: 0.1868 - val_accuracy: 0.8672 - val_loss: 0.4003
# Epoch 48/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 0.0914 - val_accuracy: 0.8889 - val_loss: 0.2889
# Epoch 49/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 717ms/step - accuracy: 0.9757 - loss: 0.1356 - val_accuracy: 0.9219 - val_loss: 0.2481
# Epoch 50/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9688 - loss: 0.1440 - val_accuracy: 0.8889 - val_loss: 0.4108
# Epoch 51/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 665ms/step - accuracy: 0.9713 - loss: 0.1237 - val_accuracy: 0.9453 - val_loss: 0.2565
# Epoch 52/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 0.0895 - val_accuracy: 0.7778 - val_loss: 0.6506
# Epoch 53/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9743 - loss: 0.1434 - val_accuracy: 0.9219 - val_loss: 0.2877
# Epoch 54/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9375 - loss: 0.1841 - val_accuracy: 0.8889 - val_loss: 0.5975
# Epoch 55/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9747 - loss: 0.1382 - val_accuracy: 0.8984 - val_loss: 0.3327
# Epoch 56/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.1040 - val_accuracy: 0.8889 - val_loss: 0.2498
# Epoch 57/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 18s 885ms/step - accuracy: 0.9687 - loss: 0.1401 - val_accuracy: 0.8750 - val_loss: 0.3583
# Epoch 58/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0693 - val_accuracy: 1.0000 - val_loss: 0.0621
# Epoch 59/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9862 - loss: 0.1237 - val_accuracy: 0.9297 - val_loss: 0.2757
# Epoch 60/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0843 - val_accuracy: 0.7778 - val_loss: 0.4800
# Epoch 61/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 693ms/step - accuracy: 0.9773 - loss: 0.0996 - val_accuracy: 0.8906 - val_loss: 0.3071
# Epoch 62/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9375 - loss: 0.1814 - val_accuracy: 0.8889 - val_loss: 0.3808
# Epoch 63/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 20s 978ms/step - accuracy: 0.9848 - loss: 0.1030 - val_accuracy: 0.9219 - val_loss: 0.3043
# Epoch 64/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0856 - val_accuracy: 0.7778 - val_loss: 0.8157
# Epoch 65/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 18s 881ms/step - accuracy: 0.9887 - loss: 0.0824 - val_accuracy: 0.9062 - val_loss: 0.2609
# Epoch 66/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9688 - loss: 0.0908 - val_accuracy: 0.7778 - val_loss: 0.6396
# Epoch 67/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 641ms/step - accuracy: 0.9834 - loss: 0.1024 - val_accuracy: 0.8750 - val_loss: 0.3242
# Epoch 68/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0788 - val_accuracy: 0.8333 - val_loss: 0.4498
# Epoch 69/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 721ms/step - accuracy: 0.9839 - loss: 0.0925 - val_accuracy: 0.8984 - val_loss: 0.2712
# Epoch 70/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0740 - val_accuracy: 0.7778 - val_loss: 0.4129
# Epoch 71/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 721ms/step - accuracy: 0.9642 - loss: 0.1210 - val_accuracy: 0.9141 - val_loss: 0.3170
# Epoch 72/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9688 - loss: 0.1262 - val_accuracy: 1.0000 - val_loss: 0.0858
# Epoch 73/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 652ms/step - accuracy: 0.9773 - loss: 0.1023 - val_accuracy: 0.9297 - val_loss: 0.2737
# Epoch 74/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0432 - val_accuracy: 0.9444 - val_loss: 0.1753
# Epoch 75/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 751ms/step - accuracy: 0.9890 - loss: 0.0980 - val_accuracy: 0.9141 - val_loss: 0.2818
# Epoch 76/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0426 - val_accuracy: 0.7778 - val_loss: 0.3791
# Epoch 77/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 681ms/step - accuracy: 0.9955 - loss: 0.0623 - val_accuracy: 0.8906 - val_loss: 0.3524
# Epoch 78/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0453 - val_accuracy: 0.8889 - val_loss: 0.3044
# Epoch 79/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 698ms/step - accuracy: 0.9801 - loss: 0.1009 - val_accuracy: 0.9141 - val_loss: 0.2871
# Epoch 80/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0471 - val_accuracy: 0.8889 - val_loss: 0.5319
# Epoch 81/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 674ms/step - accuracy: 0.9875 - loss: 0.0735 - val_accuracy: 0.8906 - val_loss: 0.3070
# Epoch 82/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 0.0898 - val_accuracy: 1.0000 - val_loss: 0.0343
# Epoch 83/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 645ms/step - accuracy: 0.9985 - loss: 0.0524 - val_accuracy: 0.9219 - val_loss: 0.2256
# Epoch 84/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0276 - val_accuracy: 0.8333 - val_loss: 0.4482
# Epoch 85/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 715ms/step - accuracy: 0.9892 - loss: 0.0800 - val_accuracy: 0.8906 - val_loss: 0.3094
# Epoch 86/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0434 - val_accuracy: 0.8889 - val_loss: 0.2087
# Epoch 87/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 16s 770ms/step - accuracy: 0.9913 - loss: 0.0717 - val_accuracy: 0.8750 - val_loss: 0.4097
# Epoch 88/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 0.9444 - val_loss: 0.2138
# Epoch 89/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 680ms/step - accuracy: 0.9961 - loss: 0.0559 - val_accuracy: 0.9141 - val_loss: 0.2418
# Epoch 90/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0689 - val_accuracy: 0.8333 - val_loss: 0.5285
# Epoch 91/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 680ms/step - accuracy: 0.9866 - loss: 0.0595 - val_accuracy: 0.8906 - val_loss: 0.3626
# Epoch 92/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0713 - val_accuracy: 1.0000 - val_loss: 0.0656
# Epoch 93/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 703ms/step - accuracy: 0.9954 - loss: 0.0540 - val_accuracy: 0.8828 - val_loss: 0.3035
# Epoch 94/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9688 - loss: 0.0859 - val_accuracy: 0.9444 - val_loss: 0.2999
# Epoch 95/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 722ms/step - accuracy: 0.9926 - loss: 0.0517 - val_accuracy: 0.9062 - val_loss: 0.2812
# Epoch 96/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0488 - val_accuracy: 0.9444 - val_loss: 0.0879
# Epoch 97/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 747ms/step - accuracy: 0.9971 - loss: 0.0382 - val_accuracy: 0.9141 - val_loss: 0.3213
# Epoch 98/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0541 - val_accuracy: 0.8889 - val_loss: 0.1510
# Epoch 99/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9947 - loss: 0.0475 - val_accuracy: 0.9453 - val_loss: 0.2338
# Epoch 100/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 0.0476 - val_accuracy: 0.7778 - val_loss: 0.5042
# Epoch 101/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 896ms/step - accuracy: 0.9846 - loss: 0.0561 - val_accuracy: 0.9531 - val_loss: 0.1842
# Epoch 102/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0355 - val_accuracy: 0.8333 - val_loss: 0.3883
# Epoch 103/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 913ms/step - accuracy: 0.9971 - loss: 0.0519 - val_accuracy: 0.9297 - val_loss: 0.2176
# Epoch 104/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0502 - val_accuracy: 0.9444 - val_loss: 0.1812
# Epoch 105/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 682ms/step - accuracy: 0.9913 - loss: 0.0484 - val_accuracy: 0.9375 - val_loss: 0.2346
# Epoch 106/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9688 - loss: 0.1003 - val_accuracy: 1.0000 - val_loss: 0.0579
# Epoch 107/125
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 653ms/step - accuracy: 0.9859 - loss: 0.0662 - val_accuracy: 0.8516 - val_loss: 0.3634
# Epoch 107: early stopping
# Restoring model weights from the end of the best epoch: 82.

# %%
# Étape 5 : Sauvegarder le modèle
model.save("actor_recognition_model_update.h5")
model.save('actor_recognition_model_update.keras')
print("Modèle sauvegardé avec succès !")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modèle sauvegardé avec succès !

# %% [markdown]
# Test du modele

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as np

# Charger le modèle
model = load_model("actor_recognition_model_night.h5")

# Charger une image de test
img_path = "/content/drive/MyDrive/Colab Notebooks/Data/cruise_test2.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Prédiction
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions)
class_labels = list(train_generator.class_indices.keys())
print(f"L'acteur prédit est : {class_labels[predicted_class]}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 10
#       8 # Charger une image de test
#       9 img_path = r"C:\Users\33658\PycharmProjects\Act-O-Matic\Celebrity Faces Cropped\Celebrity Faces Cropped\Brad Pitt002_cc1b9701.jpg"
# ---> 10 img = image.load_img(img_path, target_size=(224, 224))
#      11 img_array = image.img_to_array(img) / 255.0
#      12 img_array = np.expand_dims(img_array, axis=0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\33658\\PycharmProjects\\Act-O-Matic\\Celebrity Faces Cropped\\Celebrity Faces Cropped\\Brad Pitt002_cc1b9701.jpg'

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Charger le modèle
model = load_model("actor_recognition_model_update.h5")

# Recompiler le modèle (si nécessaire)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Configurer les chemins
train_directory = r"C:\Users\33658\Documents\Celebrity Faces Cropped"  # Dossier utilisé pour l'entraînement
test_directory = r"C:\Users\33658\Documents\Celebrity Faces Cropped\Johnny Depp"  # Dossier de test
image_size = (224, 224)  # Taille d'entrée des images

# Récupérer les noms des classes depuis les sous-dossiers
datagen = ImageDataGenerator(rescale=1.0 / 255)
generator = datagen.flow_from_directory(
    train_directory,
    target_size=image_size,
    batch_size=32,
    class_mode="categorical"
)
class_labels = list(generator.class_indices.keys())  # Liste des noms de classes
print(f"Classes détectées : {class_labels}")

# Fonction pour prédire une image
def predict_image(image_path, model):
    # Charger et prétraiter l'image
    img = image.load_img(image_path, target_size=image_size)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Faire une prédiction
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)
    confidence = predictions[0][predicted_class]

    return predicted_class, confidence

# Évaluer les performances globales
correct_predictions = 0
total_images = 0

# Parcourir les images du dossier et faire des prédictions
for img_name in os.listdir(test_directory):
    img_path = os.path.join(test_directory, img_name)

    # Vérifier que le fichier est une image
    if img_name.lower().endswith((".png", ".jpg", ".jpeg")):
        predicted_class, confidence = predict_image(img_path, model)
        true_class = class_labels.index("Johnny Depp")  # Remplacer par la classe correcte pour ce dossier

        if predicted_class == true_class:
            correct_predictions += 1
        total_images += 1

        print(f"Image: {img_name} => Acteur prédit: {class_labels[predicted_class]} (Confiance: {confidence:.2f})")
    else:
        print(f"Fichier ignoré : {img_name}")

# Calculer et afficher la performance globale
accuracy = (correct_predictions / total_images) * 100 if total_images > 0 else 0
print(f"Total d'images évaluées : {total_images}")
print(f"Prédictions correctes : {correct_predictions}")
print(f"Précision globale : {accuracy:.2f}%")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 747 images belonging to 9 classes.
# Classes détectées : ['Brad Pitt', 'Hugh Jackman', 'Johnny Depp', 'Leonardo DiCaprio', 'Natalie Portman', 'Robert Downey Jr', 'Tom Cruise', 'Tom Hanks', 'Will Smith']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# Image: 001_2288a4f6.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 002_331d0423.jpg => Acteur prédit: Johnny Depp (Confiance: 0.66)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 003_64926b97.jpg => Acteur prédit: Johnny Depp (Confiance: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 005_9406f32d.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Image: 006_8fc31fd7.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 007_1bc0bcd6.jpg => Acteur prédit: Johnny Depp (Confiance: 0.79)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 008_35d1be70.jpg => Acteur prédit: Johnny Depp (Confiance: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 009_f4a38fec.jpg => Acteur prédit: Johnny Depp (Confiance: 0.76)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 010_610eea60.jpg => Acteur prédit: Hugh Jackman (Confiance: 0.65)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 011_c826a613.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 012_563f0843.jpg => Acteur prédit: Johnny Depp (Confiance: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 013_f44c68a1.jpg => Acteur prédit: Johnny Depp (Confiance: 0.66)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 014_68248214.jpg => Acteur prédit: Johnny Depp (Confiance: 0.82)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 015_0474556e.jpg => Acteur prédit: Johnny Depp (Confiance: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Image: 016_8b4d3698.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 017_aadefe7b.jpg => Acteur prédit: Johnny Depp (Confiance: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 018_14e5366f.jpg => Acteur prédit: Johnny Depp (Confiance: 0.52)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 019_3eb26944.jpg => Acteur prédit: Johnny Depp (Confiance: 0.81)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Image: 020_6b7d8470.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 021_9ab18f1b.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Image: 022_a0763313.jpg => Acteur prédit: Johnny Depp (Confiance: 0.64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 023_4e454f96.jpg => Acteur prédit: Johnny Depp (Confiance: 0.69)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 024_bfac5f5b.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 025_4f2ec7c1.jpg => Acteur prédit: Johnny Depp (Confiance: 0.85)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 026_20c41942.jpg => Acteur prédit: Johnny Depp (Confiance: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 027_2eab41f9.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 029_30aec656.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 030_ddacf348.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 031_86ed9fca.jpg => Acteur prédit: Johnny Depp (Confiance: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 032_4b3ee537.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 033_ef398d45.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 034_52d180f0.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 035_2a1b8bcf.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 037_f2fb045b.jpg => Acteur prédit: Johnny Depp (Confiance: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Image: 038_081386a5.jpg => Acteur prédit: Johnny Depp (Confiance: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 039_13af66c8.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Image: 040_2e8934ea.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 041_6ec992c9.jpg => Acteur prédit: Johnny Depp (Confiance: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 044_18b89b8d.jpg => Acteur prédit: Johnny Depp (Confiance: 0.70)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 045_865604b0.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 046_31d6a7d8.jpg => Acteur prédit: Johnny Depp (Confiance: 0.81)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 047_6c6a66d2.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 048_8af82c54.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 049_9254f6f2.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 050_6641bd32.jpg => Acteur prédit: Johnny Depp (Confiance: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 051_2505e244.jpg => Acteur prédit: Johnny Depp (Confiance: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 052_e2e5ef6b.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 053_5b42d9d9.jpg => Acteur prédit: Johnny Depp (Confiance: 0.71)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 054_50f42b56.jpg => Acteur prédit: Johnny Depp (Confiance: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 055_cf9af56c.jpg => Acteur prédit: Johnny Depp (Confiance: 0.74)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 056_c5e6243c.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 057_ee633567.jpg => Acteur prédit: Johnny Depp (Confiance: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 058_7e4aeab8.jpg => Acteur prédit: Johnny Depp (Confiance: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 059_27a0e6f1.jpg => Acteur prédit: Johnny Depp (Confiance: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 060_3cf86eaf.jpg => Acteur prédit: Johnny Depp (Confiance: 0.83)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 061_4544a552.jpg => Acteur prédit: Johnny Depp (Confiance: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 062_23b3470a.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 066_653f2a94.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 067_5234e510.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 068_006344c5.jpg => Acteur prédit: Johnny Depp (Confiance: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Image: 069_2b2270ce.jpg => Acteur prédit: Johnny Depp (Confiance: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Image: 070_1e22daa2.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 071_d3036d43.jpg => Acteur prédit: Johnny Depp (Confiance: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 072_f2c8b6e9.jpg => Acteur prédit: Johnny Depp (Confiance: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Image: 073_71584704.jpg => Acteur prédit: Johnny Depp (Confiance: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Image: 074_bd6f3a84.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 075_21e87f0f.jpg => Acteur prédit: Johnny Depp (Confiance: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 076_b28d1fac.jpg => Acteur prédit: Johnny Depp (Confiance: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 077_5cbf1ecc.jpg => Acteur prédit: Johnny Depp (Confiance: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 078_b7114bcb.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 079_241963dc.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 080_38c2109a.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 082_742073a1.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Image: 084_3dcf601a.jpg => Acteur prédit: Johnny Depp (Confiance: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 085_e9f6ea07.jpg => Acteur prédit: Johnny Depp (Confiance: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Image: 086_f052c533.jpg => Acteur prédit: Johnny Depp (Confiance: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Image: 087_f9794152.jpg => Acteur prédit: Johnny Depp (Confiance: 0.88)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Image: 088_1fcc7b2c.jpg => Acteur prédit: Johnny Depp (Confiance: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Image: 089_2f2e823a.jpg => Acteur prédit: Johnny Depp (Confiance: 0.46)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 090_c5d1d9eb.jpg => Acteur prédit: Johnny Depp (Confiance: 0.80)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: 091_c3ad83af.jpg => Acteur prédit: Johnny Depp (Confiance: 0.78)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 093_8cb84a89.jpg => Acteur prédit: Tom Cruise (Confiance: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Image: 094_42a45a8d.jpg => Acteur prédit: Johnny Depp (Confiance: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 095_233dc3f2.jpg => Acteur prédit: Johnny Depp (Confiance: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 097_11415581.jpg => Acteur prédit: Johnny Depp (Confiance: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Image: 098_16b30dda.jpg => Acteur prédit: Johnny Depp (Confiance: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Image: 099_d88c0793.jpg => Acteur prédit: Johnny Depp (Confiance: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Image: 100_120c14bc.jpg => Acteur prédit: Johnny Depp (Confiance: 0.98)
# Total d'images évaluées : 88
# Prédictions correctes : 86
# Précision globale : 97.73%
